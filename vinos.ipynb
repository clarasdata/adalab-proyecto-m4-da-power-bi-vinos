# %%
import pandas as pd
import numpy as np

# Lee el archivo de Excel
df = pd.read_csv('wines_SPA.csv')

# %%
df.head(20)
# Out:
#                  winery                            wine  year  rating  \
# 0         Teso La Monja                           Tinto  2013     4.9
# 1                Artadi                   Vina El Pison  2018     4.9
# 2          Vega Sicilia                           Unico  2009     4.8
# 3          Vega Sicilia                           Unico  1999     4.8
# 4          Vega Sicilia                           Unico  1996     4.8
# 5          Vega Sicilia                           Unico  1998     4.8
# 6          Vega Sicilia                           Unico  2010     4.8
# 7          Vega Sicilia                           Unico  1995     4.8
# 8          Vega Sicilia  Unico Reserva Especial Edicion  2015     4.8
# 9          Vega Sicilia                           Unico  2011     4.8
# 10         Vega Sicilia  Unico Reserva Especial Edicion  2016     4.8
# 11  Pago de Carraovejas                       El Anejon  2016     4.8
# ...

# %%
df.dtypes
# Out:
# winery          object
# wine            object
# year            object
# rating         float64
# num_reviews      int64
# country         object
# region          object
# price          float64
# type            object
# body           float64
# acidity        float64
# dtype: object

# %%
df.columns
# Out:
# Index(['winery', 'wine', 'year', 'rating', 'num_reviews', 'country', 'region',
#        'price', 'type', 'body', 'acidity'],
#       dtype='object')

# %%
df['price'].unique()
# Out:
# array([995.  , 313.5 , 324.95, ...,  16.76,  24.45,  31.63])

# %%
df['price'].round(2)
# Out:
# 0        995.00
# 1        313.50
# 2        324.95
# 3        692.96
# 4        778.06
# 5        490.00
# 6        349.00
# 7        810.89
# 8        345.00
# 9        315.00
# 10       514.85
# 11       105.15
# 12       430.00
# 13       925.00
# 14       350.00
# 15       166.18
# 16      1620.00
# 17       431.36
# 18       195.63
# 19       824.43
# 20       253.00
# 21       570.51
# 22      1280.00
# 23       244.85
# 24       719.34
# 25       815.00
# 26       285.86
# 27      1410.26
# 28       813.96
# 29       435.75
# 30       369.05
# 31      1182.77
# 32       227.95
# 33       999.00
# 34       360.00
# 35      1190.00
# 36      1150.00
# 37       950.00
# 38      1021.21
# 39       544.50
# 40      1295.00
# 41       992.20
# 42      1289.44
# 43      1098.90
# 44       215.34
# 45      1094.90
# 46       423.50
# 47       239.50
# 48       175.50
# 49       194.00
# 50       381.15
# 51       584.43
# 52       555.20
# 53       445.28
# 54       189.00
# ...

# %%
df['year'] = df['year'].replace(['N.V.', np.nan], None)

# %%
df['year'].unique()
# Out:
# array(['2013', '2018', '2009', '1999', '1996', '1998', '2010', '1995',
#        '2015', '2011', '2016', '1970', '1946', '1962', '2019', '2004',
#        '1931', '1979', '2005', '2020', '2014', '1985', '1929', '2007',
#        '2012', '2017', '2008', '2006', '2000', '2003', '2002', '1991',
#        '1994', '1990', '1989', '1987', '1986', '1981', '2001', '1968',
#        '1964', '1982', '1974', '1983', '1955', '1980', '1972', '1953',
#        '1958', '1942', '1965', '1992', '1973', '1997', '1967', '1975',
#        '1910', '1961', '1954', '1988', '1969', '1951', '1928', '1976',
#        '1949', '2021', '1959', '1922', '1978', '1925'], dtype=object)

# %%
df['year'] = df['year'].astype(int)

# %%
df.dtypes
# Out:
# winery          object
# wine            object
# year             int64
# rating         float64
# num_reviews      int64
# country         object
# region          object
# price          float64
# type            object
# body           float64
# acidity        float64
# dtype: object

# %%
df.head(20)
# Out:
#                  winery                            wine  year  rating  \
# 0         Teso La Monja                           Tinto  2013     4.9
# 1                Artadi                   Vina El Pison  2018     4.9
# 2          Vega Sicilia                           Unico  2009     4.8
# 3          Vega Sicilia                           Unico  1999     4.8
# 4          Vega Sicilia                           Unico  1996     4.8
# 5          Vega Sicilia                           Unico  1998     4.8
# 6          Vega Sicilia                           Unico  2010     4.8
# 7          Vega Sicilia                           Unico  1995     4.8
# 8          Vega Sicilia  Unico Reserva Especial Edicion  2015     4.8
# 9          Vega Sicilia                           Unico  2011     4.8
# 10         Vega Sicilia  Unico Reserva Especial Edicion  2016     4.8
# 11  Pago de Carraovejas                       El Anejon  2016     4.8
# ...

# %%
df['region'].unique()
# Out:
# array(['Toro', 'Vino de Espana', 'Ribera del Duero', 'Montilla-Moriles',
#        'Jumilla', 'Jerez-Xeres-Sherry', 'Priorato', 'Rioja', 'Bierzo',
#        'Castilla y Leon', 'Campo de Borja', 'Cadiz', 'Cava',
#        'Jerez Palo Cortado', 'Manzanilla', 'Valdeorras', 'Emporda',
#        'Rioja Alta', 'Alicante', 'Somontano', 'Dominio de Valdepusa',
#        'Ribeiro', 'Mallorca', 'Yecla', 'Cigales', 'Utiel-Requena',
#        'Navarra', 'Rioja Alavesa', 'Costers del Segre', 'Sardon de Duero',
#        'Malaga', 'Cataluna', 'Rueda', 'Jerez Pedro Ximenes (PX)',
#        'Montsant', 'Conca de Barbera', 'Rias Baixas', 'Jerez Amontillado',
#        'Tierra del Vino de Zamora', 'Penedes', 'Dehesa del Carrizal',
#        'Madrid', 'Carinena', 'Condado de Huelva', 'Almansa',
#        'Jerez Cream', 'Valencia', 'Sierras de Malaga', 'Ribeira Sacra',
#        'El Terrerazo', 'Jerez Oloroso', 'Castilla', 'Alella',
#        'Pla i Llevant', 'Pla de Bages', 'Pago Calzadilla', 'Andalucia',
# ...

# %%
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None)

# %%
df['winery'].unique()
# Out:
# array(['Teso La Monja', 'Artadi', 'Vega Sicilia', 'Pago de Carraovejas',
#        'Toro Albala', 'Bodegas El Nido', 'Valdespino',
#        'Dominio de Pingus', 'Alvaro Palacios', 'Ordonez',
#        'Bodegas Valduero', 'Vina Sastre', 'Sierra Cantabria',
#        'Descendientes de J. Palacios', 'La Rioja Alta',
#        'Marques de Murrieta', 'Vinedos de Paganos', 'Emilio Moro',
#        'Quinta de la Quietud', 'Bodegas Mauro',
#        'Bodega Contador (Benjamin Romeo)', 'Remirez de Ganuza',
#        'Bodegas San Roman', 'Pago de Los Capellanes', 'Bodega Numanthia',
#        'Alto Moncayo', 'Mas Doix', 'Finca Moncloa', 'Bodegas Roda',
#        'Martinet', 'Recaredo', 'Clos Erasmus', 'Barbadillo',
#        'Gonzalez-Byass', 'Bodegas Amaren', 'Alvear', 'Equipo Navazos',
#        'Morca', 'Territorio Luthier', 'Rafael Palacios', 'Terra Remota',
#        'Dehesa de Los Canonigos', 'Miguel Merino', 'Gutierrez de la Vega',
# ...

# %%
df['winery'].value_counts()
# Out:
# Contino                                             457
# Artadi                                              261
# La Rioja Alta                                       254
# Sierra Cantabria                                    237
# Matarromera                                         232
# Vina Pedrosa                                        230
# Imperial                                            228
# Losada                                              227
# Portal del Priorat                                  225
# Ramon Bilbao                                        225
# Sei Solo                                            225
# Matsu                                               224
# Bodegas La Horra                                    223
# Campillo                                            223
# Lustau                                              223
# La Vicalanda                                        223
# Conreria d'Scala Dei                                223
# ...

# %%
df['region'].value_counts()
# Out:
# Rioja                              2440
# Ribera del Duero                   1413
# Priorato                            686
# Toro                                300
# Vino de Espana                      263
# Rias Baixas                         252
# Jerez-Xeres-Sherry                  247
# Bierzo                              244
# Mallorca                            237
# Alicante                            233
# Costers del Segre                   232
# Ribeiro                             230
# El Terrerazo                        222
# Castilla y Leon                      51
# Cava                                 34
# Jumilla                              26
# Montilla-Moriles                     26
# Emporda                              25
# Sardon de Duero                      24
# Penedes                              22
# Montsant                             20
# Rueda                                17
# Campo de Borja                       16
# ...

# %%
bodegas = {'Teso La Monja': 'Toro',
    'Artadi': 'Rioja',
    'Vega Sicilia': 'Ribera del Duero',
    'Pago de Carraovejas': 'Ribera del Duero',
    'Toro Albala': 'Montilla-Moriles',
    'Bodegas El Nido': 'Jumilla',
    'Valdespino': 'Jerez',
    'Dominio de Pingus': 'Ribera del Duero',
    'Alvaro Palacios': 'Priorat',
    'Ordonez': 'Málaga',
    'Bodegas Valduero': 'Ribera del Duero',
    'Vina Sastre': 'Ribera del Duero',
    'Sierra Cantabria': 'Rioja',
    'Descendientes de J. Palacios': 'Bierzo',
    'La Rioja Alta': 'Rioja',
    'Marques de Murrieta': 'Rioja',
    'Vinedos de Paganos': 'Rioja',
    'Emilio Moro': 'Ribera del Duero',
    'Quinta de la Quietud': 'Toro',
    'Bodegas Mauro': 'Vinos de la Tierra de Castilla y León',
    'Bodega Contador (Benjamin Romeo)': 'Rioja',
    'Remirez de Ganuza': 'Rioja',
    'Bodegas San Roman': 'Toro',
    'Pago de Los Capellanes': 'Ribera del Duero',
    'Bodega Numanthia': 'Toro',
    'Alto Moncayo': 'Campo de Borja',
    'Mas Doix': 'Priorat',
    'Finca Moncloa': 'Vinos de la Tierra de Cádiz',
    'Bodegas Roda': 'Rioja',
    'Martinet': 'Priorat',
    'Recaredo': 'Cava',
    'Clos Erasmus': 'Priorat',
    'Barbadillo': 'Jerez',
    'Gonzalez-Byass': 'Jerez',
    'Bodegas Amaren': 'Rioja',
    'Alvear': 'Montilla-Moriles',
    'Equipo Navazos': 'Vinos de la Tierra de Cádiz',
    'Morca': 'Vinos de la Tierra de Castilla',
    'Territorio Luthier': 'Vinos de la Tierra de Castilla',
    'Rafael Palacios': 'Valdeorras',
    'Terra Remota': 'Empordà',
    'Dehesa de Los Canonigos': 'Ribera del Duero',
    'Miguel Merino': 'Rioja',
    'Gutierrez de la Vega': 'Alicante',
    'Alion': 'Ribera del Duero',
    'Aalto': 'Ribera del Duero',
    'Carmelo Rodero': 'Ribera del Duero',
    'Dominio del Bendito': 'Toro',
    "Mas d'en Gil": 'Priorat',
    'Casa Castillo': 'Jumilla',
    'Matarromera': 'Ribera del Duero',
    'Nin-Ortiz': 'Priorat',
    'Vinas del Vero': 'Somontano',
    'Marques de Riscal': 'Rioja',
    'Arzuaga': 'Ribera del Duero',
    'Bodegas Mas Alta': 'Priorat',
    'Dominio de Calogia': 'Jumilla',
    'Tomas Postigo': 'Vinos de la Tierra de Castilla y León',
    'Cal Pla': 'Priorat',
    'Ossian': 'Vinos de la Tierra de Castilla y León',
    'Cepa 21': 'Ribera del Duero',
    'Bodegas Vilano': 'Ribera del Duero',
    'Allende': 'Rioja',
    'Costers del Siurana': 'Priorat',
    'Hacienda Monasterio': 'Ribera del Duero',
    'Castillo Perelada': 'Empordà',
    'Osborne': 'Jerez',
    'Ysios': 'Rioja',
    'Marques de Grinon': 'Vinos de la Tierra de Castilla',
    'Contino': 'Rioja',
    'Gramona': 'Cava',
    'Dominio del Aguila': 'Ribera del Duero',
    'Hacienda Solano': 'Vinos de la Tierra de Castilla',
    'Francisco Garcia Perez': 'Vinos de la Tierra de Castilla',
    'Anima Negra': 'Vi de la Terra Mallorca',
    'Castano': 'Yecla',
    'La Legua': 'Vinos de la Tierra de Castilla y León',
    'Castillo de Cuzcurrita': 'Rioja',
    'Oxer Wines': 'Vinos de la Tierra de Castilla y León',
    'Bodegas Yuste': 'Jerez',
    'Bodegas 6o Elemento - Vino Sexto Elemento': 'Vinos de la Tierra de Castilla',
    'Proyecto Garnachas de Espana': 'Calatayud',
    'Casal de Arman': 'Ribeiro',
    'Vall Llach': 'Priorat',
    'Pago de Larrainzar': 'Navarra',
    'Ukan Winery': 'Vinos de la Tierra de Castilla',
    'Vina Real': 'Rioja',
    'Dominio de Atauta': 'Ribera del Duero',
    'Micro Bio (MicroBio)': 'Vinos de la Tierra de Castilla y León',
    'Terroir Al Limit Soc. Lda': 'Priorat',
    'Finca Torremilanos': 'Ribera del Duero',
    'Huerta de Albala': 'Vinos de la Tierra de Cádiz',
    'Gomez Cruzado': 'Rioja',
    'Castell d\'Encus': 'Costers del Segre',
    'Abadia Retuerta': 'Vinos de la Tierra de Castilla y León',
    'Enate': 'Somontano',
    'Benjamin de Rothschild - Vega Sicilia': 'Ribera del Duero',
    'Bodegas Aragonesas': 'Campo de Borja',
    'Telmo Rodriguez': 'Vinos de la Tierra de Castilla y León',
    'Acustic Celler': 'Montsant',
    'Vina Pedrosa': 'Ribera del Duero',
    'Pintia': 'Toro',
    'Belondrade': 'Rueda',
    'Muga': 'Rioja',
    'Clos Mogador': 'Priorat',
    'Bodegas Tradicion': 'Jerez',
    'Senorio de San Vicente': 'Rioja',
    'Francisco Barona': 'Vinos de la Tierra de Castilla y León',
    'Juan Gil': 'Jumilla',
    'Lan': 'Rioja',
    'R. Lopez de Heredia': 'Rioja',
    'Adama Wines': 'Bierzo',
    'Milsetentayseis': 'Vinos de la Tierra de Castilla y León',
    'Espectacle del Montsant': 'Montsant',
    'Tinto Pesquera': 'Ribera del Duero',
    'Ferrer Bobet': 'Priorat',
    'Familia Torres': 'Penedés',
    'Pazo Barrantes': 'Rias Baixas',
    'Tio Pepe': 'Jerez',
    'Cruz de Alba': 'Ribera del Duero',
    'Emilio Rojo': 'Ribeiro',
    'Dominio de Es': 'Vinos de la Tierra de Castilla y León',
    'Jesus Madrazo': 'Vinos de la Tierra de Castilla y León',
    'Bodegas Naluar & Acediano': 'Rioja',
    'Marques de Caceres': 'Rioja',
    'Trus': 'Ribera del Duero',
    'Mestres': 'Cava',
    'Chivite': 'Navarra',
    'Bodega Ribas': 'Binissalem-Mallorca',
    'Vinas del Cenit': 'Vinos de la Tierra de Castilla y León',
    'Mas del Serral': 'Conca de Barberà',
    'Cervoles': 'Costers del Segre',
    'Diez Merito': 'Jerez',
    'Marques de Burgos': 'Vinos de la Tierra de Castilla y León',
    'Penafiel': 'Ribera del Duero',
    'Tobia': 'Rioja',
    'Tresmano - Tr3smano': 'Vinos de la Tierra de Castilla y León',
    'Sei Solo': 'Vinos de la Tierra de Castilla y León',
    'Finca Villacreces': 'Ribera del Duero',
    'Virgen de la Asuncion': 'Vinos de la Tierra de Castilla y León',
    'Romate': 'Jerez',
    'Sara Perez y Rene Barbier': 'Montsant',
    'Dehesa del Carrizal': 'Vinos de la Tierra de Castilla',
    'Tarsus': 'Ribera del Duero',
    'Beronia': 'Rioja',
    'Monte Real': 'Rioja',
    'Divina Proporcion': 'Ribera del Duero',
    'Vina al Lado de la Casa': 'Vinos de la Tierra de Castilla y León',
    'Marques de la Concordia': 'Vinos de la Tierra de Castilla y León',
    'Agusti Torello Mata': 'Cava',
    'Dominio de Cair': 'Ribera del Duero',
    'Valquejigoso': 'Vinos de la Tierra de Castilla',
    'Veigamoura': 'Vinos de la Tierra de Castilla',
    'Vizcarra': 'Ribera del Duero',
    'Legaris': 'Ribera del Duero',
    'Federico Paternina': 'Rioja',
    'Vinicola Real': 'Rueda',
    'Losada': 'Bierzo',
    "Clos d'Agon": 'Catalunya',
    'Sacristia AB': 'Montilla-Moriles',
    'Uvaguilera Aguilera': 'Ribera del Duero',
    'Emilio Hidalgo': 'Jerez',
    'Altos del Terral': 'Vinos de la Tierra de Castilla',
    'El Regajal': 'Vinos de Madrid',
    'Valderiz': 'Ribera del Duero',
    'Jose Pariente': 'Rueda',
    'Amos Baneres': 'Vinos de la Tierra de Castilla',
    'Scala Dei': 'Priorat',
    'Bodegas Valdelana': 'Rioja',
    'Abel Mendoza Monge': 'Rioja',
    'Anayon': 'Vinos de la Tierra de Castilla',
    'Sierra Salinas': 'Alicante',
    'Vinos Sanz': 'Rueda',
    'Cerro San Cristobal': 'Ribera del Duero',
    'Altos de Rioja': 'Rioja',
    'Bodegas Celler Francisco Castillo - Clos Dominic': 'Priorat',
    'La Vinya del Vuit': 'Montsant',
    'Venus la Universal': 'Montsant',
    'Pedralonga': 'Rias Baixas',
    'Atalaya': 'Almansa',
    'Matsu': 'Toro',
    'Marques de Vargas': 'Rioja',
    'Volver': 'Vinos de la Tierra de Castilla',
    'Tridente': 'Vinos de la Tierra de Castilla y León',
    'Ausas': 'Montsant',
    'Cillar de Silos': 'Ribera del Duero',
    'Imperial': 'Rioja',
    'Ramos-Paul': 'Jerez',
    'Bodega de Bardos': 'Ribera del Duero',
    'Rodriguez Sanzo': 'Ribera del Duero',
    'Antidoto': 'Ribera del Duero',
    'Bosque de Matasnos': 'Ribera del Duero',
    'Altanza': 'Rioja',
    'Remelluri': 'Rioja',
    'Perinet': 'Priorat',
    'La Vicalanda': 'Rioja',
    'Monovar': 'Jumilla',
    'Alvaro Domecq': 'Jerez',
    'Los Aguilares': 'Sierras de Málaga',
    'Bodega Rento': 'Vinos de la Tierra de Castilla',
    'Dominio do Bibei': 'Ribeira Sacra',
    'Marco Abella': 'Priorat',
    'Javier Sanz Viticultor': 'Rueda',
    'Protos': 'Ribera del Duero',
    'Harveys': 'Jerez',
    'Orben': 'Rioja',
    'Jaro': 'Vinos de la Tierra de Castilla y León',
    'Bodegas Ximenez-Spinola': 'Vinos de la Tierra de Cádiz',
    'Bodegas El Paraguas': 'Vinos de la Tierra de Castilla',
    'Mustiguillo': 'Vinos de la Tierra de Castilla',
    'Vina Pomal': 'Rioja',
    'Astrales': 'Ribera del Duero',
    'Merum Priorati': 'Priorat',
    'Hacienda Lopez de Haro': 'Rioja',
    'Cayetano del Pino': 'Vinos de la Tierra de Cádiz',
    'La Unica': 'Vinos de la Tierra de Castilla',
    'Pazo Senorans': 'Rias Baixas',
    'Fefinanes': 'Rias Baixas',
    'Resalte': 'Ribera del Duero',
    'Figuero': 'Ribera del Duero',
    'Pinea': 'Vinos de la Tierra de Castilla y León',
    'Portal del Priorat': 'Priorat',
    'Cims de Porrera': 'Priorat',
    'Casa Rojo': 'Vinos de la Tierra de Castilla',
    'Murua': 'Rioja',
    'Vinyes Domenech': 'Montsant',
    'Pago de Vallegarcia': 'Vinos de la Tierra de Castilla',
    'Eulogio Pomares': 'Rias Baixas',
    'Sangenis I Vaque': 'Priorat',
    'Delgado Zuleta': 'Jerez',
    'VALENCISO': 'Rioja',
    'Mas Perinet': 'Priorat',
    'Luis A. Rodriguez Vazquez': 'Rias Baixas',
    'Chozas Carrascal': 'Utiel-Requena',
    'Alonso del Yerro': 'Ribera del Duero',
    'Clos Figueras': 'Priorat',
    'Bodegas Monte La Reina': 'Vinos de la Tierra de Castilla y León',
    'Ontanon': 'Rioja',
    'Alta Alella': 'Cava',
    'Bodega Elias Mora': 'Toro',
    'Joan Simo': 'Vinos de la Tierra de Mallorca',
    'Can Axartell': 'Vinos de la Tierra de Mallorca',
    'Juan Pinero': 'Jerez',
    'Mas Llunes': 'Emporda',
    'Bodegas Frontaura': 'Vinos de la Tierra de Castilla y León',
    'Roig Parals': 'Cava',
    'Avgvstvs': 'Tarragona',
    'Jorge Ordonez': 'Sierras de Malaga',
    'Ramon Bilbao': 'Rioja',
    'Leda': 'Vinos de la Tierra de Castilla y León',
    'Enric Soler': 'Penedes',
    'Es Fangar': 'Vinos de la Tierra de Mallorca',
    'Cal Batllet - Celler Ripoll Sans': 'Priorat',
    'Llopart': 'Cava',
    'Portia': 'Ribera del Duero',
    'Ostatu': 'Rioja',
    'Finca Valpiedra': 'Rioja',
    'Baigorri': 'Rioja',
    'Vivaltus': 'Vinos de la Tierra de Castilla y León',
    'Comenge': 'Ribera del Duero',
    'Collbaix Celler El Moli': 'Catalunya',
    'Martinez Lacuesta': 'Rioja',
    'Pujanza': 'Rioja',
    'Albet i Noya': 'Penedes',
    'Olivier Riviere': 'Rioja',
    'Bodegas Tierra': 'Sierras de Malaga',
    'Torre de Ona': 'Rioja',
    'Do Ferreiro (Bodegas Gerardo Mendez)': 'Rias Baixas',
    'Martin Codax': 'Rias Baixas',
    'Vinedos Hermanos Hernaiz': 'Rioja',
    'Freixenet': 'Cava',
    'Azpilicueta': 'Rioja',
    'Veronica Salgado': 'Vinos de la Tierra de Castilla y León',
    'Clos Galena': 'Priorat',
    'Bodegas Imperiales - Abadia de San Quirce': 'Ribera del Duero',
    'Marta Mate': 'Sierras de Malaga',
    'Venta Las Vacas': 'Vinos de la Tierra de Castilla y León',
    'Pago Calzadilla': 'Vinos de la Tierra de Castilla y León',
    'Vivanco': 'Rioja',
    'Fernandez Gao': 'Vinos de la Tierra de Castilla y León',
    'Museum': 'Cigales',
    'Farina': 'Rias Baixas',
    'Galindo San Millan': 'Cigales',
    'Bodegas Casa Primicia': 'Rioja',
    'Castell Miquel': 'Binissalem/Mallorca',
    'Barco del Corneta': 'Vinos de la Tierra de Castilla y León',
    "Joan d'Anguera": 'Montsant',
    'Xaloc': 'Penedes',
    'Carlos Moro': 'Ribera del Duero',
    'Bodegas Luis Perez': 'Jerez',
    'Ladairo': 'Ribeira Sacra',
    "Conreria d'Scala Dei": 'Priorat',
    'Traslascuestas': 'Ribera del Duero',
    'Lopez Cristobal': 'Ribera del Duero',
    'Codorniu': 'Cava',
    'Sota els Angels': 'Penedes',
    'Berceo': 'Rioja',
    'Mas Blanch I Jove': 'Costers del Segre',
    'Carlos Serres': 'Rioja',
    'David Moreno': 'Rioja',
    'Edra': 'Vinos de la Tierra de Castilla y León',
    'Valdelosfrailes': 'Vinos de la Tierra de Castilla y León',
    'Briego': 'Ribera del Duero',
    'Guillem Carol - Cellers Carol Valles': 'Cava',
    'Barahonda': 'Yecla',
    'Particular': 'Calatayud',
    'Bodegas Frontonio': 'Valdejalon',
    'Bodegas Asenjo & Manso': 'Ribera del Duero',
    'Luis Canas': 'Rioja',
    'Garmon': 'Ribera del Duero',
    'Williams & Humbert': 'Jerez',
    'Condado de Haza': 'Ribera del Duero',
    'Lustau': 'Jerez',
    'Bodegas Faustino': 'Rioja',
    'St. Petroni': 'Rias Baixas',
    'Llanos Negros': 'La Palma',
    'Aster': 'Ribera del Duero',
    'Avancia': 'Valdeorras',
    'Marques de Tomares': 'Rioja',
    'Quinta Sardonia': 'Vinos de la Tierra de Castilla y León',
    'Abadal': 'Pla de Bages',
    'Hermanos Pecina': 'Rioja',
    'Biniagual': 'Binissalem/Mallorca',
    'Breca': 'Calatayud',
    'Pradorey': 'Ribera del Duero',
    'Terras Gauda': 'Rias Baixas',
    'Bodega Tesalia': 'Sierras de Malaga',
    'Pazo de Rubianes': 'Rias Baixas',
    'Godeval': 'Valdeorras',
    'Bodegas Olarra': 'Rioja',
    'Taron': 'Rioja',
    'Sonsierra': 'Rioja',
    'Vins Miquel Gelabert': 'Binissalem/Mallorca',
    'El Grillo y La Luna': 'Somontano',
    'De Moya': 'Vinos de la Tierra de Castilla y León',
    'Campillo': 'Rioja',
    'Jean Leon': 'Penedes',
    'Bodegas Ateca': 'Calatayud',
    'Bodega Campo Eliseo': 'Vinos de la Tierra de Castilla y León',
    'Fernandez de Pierola': 'Rioja',
    'De Muller': 'Tarragona',
    'Monteabellon': 'Ribera del Duero',
    'Pepe Mendoza Casa Agricola': 'Alicante',
    'Vinos Guerra': 'Tierra de León',
    'Neo': 'Ribera del Duero',
    "Terra d'Uro": 'Toro',
    'Zarate': 'Rias Baixas',
    'Noelia Bebelia': 'Campo de Borja',
    'Marti Fabra': 'Penedes',
    'Palmeri Sicilia': 'Vinos de la Tierra de Castilla y León',
    'Mas Que Vinos': 'Vinos de la Tierra de Castilla y León',
    'Bodegas Estraunza': 'Rioja',
    'Pittacum': 'Bierzo',
    'Bodega Sommos': 'Somontano',
    'Celler de Capcanes': 'Montsant',
    'Arinzano': 'Penedes',
    'Pago del Vostal': 'Vinos de Madrid',
    'Habla': 'Vinos de la Tierra de Extremadura',
    'Rodriguez de Vera': 'La Mancha',
    'Callejuela': 'Jerez',
    'El Maestro Sierra': 'Jerez',
    'Paco & Lola': 'Rias Baixas',
    'Valtravieso': 'Ribera del Duero',
    'Costers del Priorat': 'Priorat',
    'Bodegas Urium': 'Toro',
    'Bodega Otazu': 'Navarra',
    'Perez Barquero': 'Montilla-Moriles',
    'Oller del Mas': 'Pla de Bages',
    'Bodegas Clunia': 'Ribera del Duero',
    'Bodegas Ochoa': 'Navarra',
    "Ca l'Apotecari": 'Penedes',
    'Josep Grau Viticultor': 'Priorat',
    'Fos': 'Vinos de la Tierra de Castilla y León',
    'Hacienda Grimon': 'Rioja',
    'Capafons-Osso': 'Priorat',
    'Can Rafols dels Caus': 'Penedes',
    'Raul Perez': 'Bierzo',
    'Dominio de la Vega': 'Valencia',
    'Juve & Camps': 'Cava',
    'Mas de les Pereres': 'Tarragona',
    'Guilera': 'Cava',
    "l'Infernal Combier Fischer Gerin": 'Rias Baixas',
    'Jorge Piernas': 'Vinos de la Tierra de Castilla y León',
    'Balandro': 'Montilla-Moriles',
    'M. Antonio de la Riva': 'Vinos de la Tierra de Castilla y León',
    'Espelt': 'Emporda',
    'Bodegas Arfe': 'Vinos de la Tierra de Castilla y León',
    'Real de Asua': 'Rioja',
    'Vinyes dels Aspres': 'Emporda',
    'Valserrano': 'Rioja',
    'Shaya': 'Rueda',
    'Finca Rio Negro': 'Vinos de la Tierra de Castilla y León',
    'Loxera': 'Montsant',
    'Dominio Fournier': 'Ribera del Duero',
    'Bodegas Yzaguirre': 'Tarragona',
    'Neton': 'Jumilla',
    'Bodega Aida i Luis': 'Montsant',
    'Cartoixa de Montsalvat': 'Penedes',
    'El Lagar de Isilla': 'Ribera del Duero',
    'Anibal de Otero': 'Vinos de la Tierra de Castilla y León',
    'Altos del Enebro': 'Bierzo',
    'Albamar': 'Rias Baixas',
    'Can Bas': 'Penedes',
    'Atlantida': 'Valdeorras',
    'Atlan & Artisan': 'Vinos de la Tierra de Castilla y León',
    'Olivardots': 'Emporda',
    'Lar de Paula': 'Rioja',
    'La Val': 'Rias Baixas',
    'Tres Piedras': 'Vinos de la Tierra de Castilla y León',
    'Javi Revert': 'Alicante',
    'Lambuena': 'Ribera del Duero',
    'Attis': 'Rias Baixas',
    'San Cobate': 'Vinos de la Tierra de Castilla y León',
    'Santa Petronila': 'Calatayud',
    'Jimenez-Landi': 'Mentrida',
    'Hidalgo (La Gitana)': 'Jerez',
    'Gallina de Piel': 'Vinos de la Tierra de Castilla y León',
    'Arid': 'Vinos de Madrid',
    'Bodegas Reyes': 'Vinos de la Tierra de Castilla y León',
    'Hugas de Batlle': 'Cava',
    'Bodegas Arrocal': 'Ribera del Duero',
    'Buil & Gine': 'Priorat',
    'Castell del Remei': 'Costers del Segre',
    'Valdubon': 'Ribera del Duero',
    'Bodegas Y Vinedos Alilian': 'Rueda',
    'Sebio': 'Rias Baixas',
    'Goyo Garcia Viadero': 'Ribera del Duero',
    'Santiago Ruiz': 'Rias Baixas',
    'Mauro Estevez': 'Bierzo',
    'Mas Bertran': 'Penedes',
    'Bodegas Gama': 'Campo de Borja',
    'Edetaria': 'Terra Alta',
    'Hacienda Zorita Natural Reserve': 'Vinos de la Tierra de Castilla y León',
    'Ton Rimbau': 'Penedes',
    'Can Xanet': 'Pla de Bages',
    'A Coroa': 'Valdeorras',
    'Alonso & Pedrajo': 'Toro',
    'Mandia Vell': 'Tarragona',
    'Bodega Juan Carlos Sancha': 'Calatayud',
    'Valdecuevas': 'Rueda',
    'Algueira': 'Ribeira Sacra',
    'Mocen': 'Vinos de la Tierra de Castilla y León',
    'Estones': 'Montsant',
    'Bodega Tameran': 'Gran Canaria',
    'Inurrieta': 'Navarra',
    'Flor de Chasna': 'Vinos de la Tierra de Castilla y León',
    'Lagar de Sabariz': 'Rias Baixas',
    'Naia': 'Rueda',
    'AGE': 'Montsant',
    'Navajas': 'Rioja',
    'Vinyes del Terrer': 'Tarragona',
    'Cepas Familiares': 'Vinos de la Tierra de Castilla y León',
    'Dominio de Loalva': 'Jerez',
    'Zifar': 'Campo de Borja',
    'Bordalas Garcia': 'Rioja',
    'Rimarts': 'Cava',
    'Pinna Fidelis': 'Ribera del Duero',
    'Loess': 'Ribera del Duero',
    'Dominio de Anza': 'Vinos de la Tierra de Castilla y León',
    'Samsara': 'Montsant',
    'Cuentavinas': 'Jerez',
    'Felix Solis': 'Vinos de la Tierra de Castilla y León',
    'El Coto': 'Rioja',
    'Mar de Frades': 'Rias Baixas',
    'Montecastro': 'Ribera del Duero',
    'Bodegas La Horra': 'Ribera del Duero',
    'Baluarte': 'Navarra',
    'Hispano Suizas': 'Utiel-Requena',
    'Murviedro': 'Valencia',
    'Diez Caballero': 'Rioja',
    'Vegalfaro': 'Utiel-Requena',
    'Palacios Remondo': 'Rioja',
    'Fernando de Castilla': 'Jerez',
    'Bohorquez': 'Vinos de la Tierra de Castilla y León',
    'Adega Familiar Eladio Pineiro': 'Rias Baixas',
    'Culebron': 'Jumilla',
    'Enrique Mendoza': 'Alicante',
    'Clos Pons': 'Costers del Segre',
    'Ramon do Casar': 'Rias Baixas',
    'Binigrau': 'Pla de Mallorca'}

# %%
bodegas_agrp = {v: k for k, v in bodegas.items()}
denominacion_origen = {}
for bodega, denominacion in bodegas.items():
    denominacion_origen.setdefault(denominacion, []).append(bodega)

# %%
denominacion_origen
# Out:
# {'Toro': ['Teso La Monja',
#   'Quinta de la Quietud',
#   'Bodegas San Roman',
#   'Bodega Numanthia',
#   'Dominio del Bendito',
#   'Pintia',
#   'Matsu',
#   'Bodega Elias Mora',
#   "Terra d'Uro",
#   'Bodegas Urium',
#   'Alonso & Pedrajo'],
#  'Rioja': ['Artadi',
#   'Sierra Cantabria',
#   'La Rioja Alta',
#   'Marques de Murrieta',
#   'Vinedos de Paganos',
#   'Bodega Contador (Benjamin Romeo)',
#   'Remirez de Ganuza',
#   'Bodegas Roda',
#   'Bodegas Amaren',
#   'Miguel Merino',
#   'Marques de Riscal',
#   'Allende',
#   'Ysios',
#   'Contino',
#   'Castillo de Cuzcurrita',
#   'Vina Real',
#   'Gomez Cruzado',
#   'Muga',
#   'Senorio de San Vicente',
#   'Lan',
#   'R. Lopez de Heredia',
#   'Bodegas Naluar & Acediano',
#   'Marques de Caceres',
#   'Tobia',
#   'Beronia',
#   'Monte Real',
#   'Federico Paternina',
#   'Bodegas Valdelana',
#   'Abel Mendoza Monge',
#   'Altos de Rioja',
#   'Marques de Vargas',
#   'Imperial',
#   'Altanza',
#   'Remelluri',
# ...

# %%
df['denominacion_origen'] = df['winery'].map({value: key for key, values in denominacion_origen.items() for value in values})

# %%
df.head(20)
# Out:
#                  winery                            wine  year  rating  \
# 0         Teso La Monja                           Tinto  2013     4.9
# 1                Artadi                   Vina El Pison  2018     4.9
# 2          Vega Sicilia                           Unico  2009     4.8
# 3          Vega Sicilia                           Unico  1999     4.8
# 4          Vega Sicilia                           Unico  1996     4.8
# 5          Vega Sicilia                           Unico  1998     4.8
# 6          Vega Sicilia                           Unico  2010     4.8
# 7          Vega Sicilia                           Unico  1995     4.8
# 8          Vega Sicilia  Unico Reserva Especial Edicion  2015     4.8
# 9          Vega Sicilia                           Unico  2011     4.8
# 10         Vega Sicilia  Unico Reserva Especial Edicion  2016     4.8
# 11  Pago de Carraovejas                       El Anejon  2016     4.8
# ...

# %%
df.to_csv('vinos.csv', index=False)
